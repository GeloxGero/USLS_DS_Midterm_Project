# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('data.csv')

# Get the data for the bar graph
x = df['WEIGHT']
y = df['PAIN1']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Weight and Pain in the Neck')
plt.xlabel('Weight')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
y = df['PAIN2']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Weight and Pain in the Thoracic')
plt.xlabel('Weight')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
y = df['PAIN3']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Weight and Pain in the Lumbar')
plt.xlabel('Weight')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
y = df['PAIN4']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Weight and Pain in the Sacral')
plt.xlabel('Weight')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
x = df['AGE']
y = df['PAIN1']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Age and Pain in the Neck')
plt.xlabel('Age')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
x = df['AGE']
y = df['PAIN2']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Age and Pain in the Thoracic')
plt.xlabel('Age')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
x = df['AGE']
y = df['PAIN3']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Age and Pain in the Lumbar')
plt.xlabel('Age')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
x = df['AGE']
y = df['PAIN4']

# Create the bar graph
plt.bar(x, y)

# Set the title and labels
plt.title('Age and Pain in the Sacra')
plt.xlabel('Age')
plt.ylabel('Pain')

# Display the graph
plt.show()

# %%
# Create the scatter plot
plt.scatter(df['SEX'], df['PAIN1'])

# Set the title and labels
plt.title('Scatter Plot of ' + "Sex" + ' vs. ' + "Pain in the Neck")
plt.xlabel("Sex")
plt.ylabel("Pain")

# Show the plot
plt.show()

# %%
# Create the scatter plot
plt.scatter(df['SEX'], df['PAIN2'])

# Set the title and labels
plt.title('Scatter Plot of ' + "Sex" + ' vs. ' + "Pain in the Thoracic")
plt.xlabel("Sex")
plt.ylabel("Pain")

# Show the plot
plt.show()

# %%
# Create the scatter plot
plt.scatter(df['SEX'], df['PAIN3'])

# Set the title and labels
plt.title('Scatter Plot of ' + "Sex" + ' vs. ' + "Pain in the Lumbar")
plt.xlabel("Sex")
plt.ylabel("Pain")

# Show the plot
plt.show()

# %%
# Create the scatter plot
plt.scatter(df['SEX'], df['PAIN4'])

# Set the title and labels
plt.title('Scatter Plot of ' + "Sex" + ' vs. ' + "Pain in the Sacral")
plt.xlabel("Sex")
plt.ylabel("Pain")

# Show the plot
plt.show()
